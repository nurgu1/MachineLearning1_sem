# %% [markdown]
# <a href="https://colab.research.google.com/github/nurgu1/MachineLearning1_sem/blob/main/class5/class5_practice_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Build a Simple Machine Learning Pipeline in Python
#
# We use the Wine Quality Dataset from the UCI Machine Learning Repository. It has chemical properties of different wines (like acidity, sugar levels, pH) and their quality ratings.

# %% [markdown]
# ##1. Import Libraries & the Dataset
# We need to import some essential libraries. These handle everything from loading and processing data to building and evaluating our model. We need these libraries to work with the dataset (pandas), handle preprocessing (StandardScaler, SimpleImputer), split the data (train_test_split), and build a seamless workflow (Pipeline). They make everything more structured and efficient.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report, accuracy_score

# %% [markdown]
# We’re using the Wine Quality Dataset from UCI. This step fetches the data directly from the web and loads it into a DataFrame.

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
data = _______________
print("First 5 rows of the dataset:")
print(____________)

# %% [markdown]
# ##2. Separate Features and Target
#
# We need to split the dataset into features (X) and the target variable (y). Since this is about predicting if a wine is “good” or “bad,” we’ll simplify it into a binary classification problem.
#
# This setup prepares the data for training. The original target values are ratings on a scale, but by simplifying them to “good” or “bad,” we can focus on building the pipeline without worrying about multi-class problems.

# %%
X = data.drop(______________________)
y = np.where(_______________________)  # 1 for good quality, 0 for bad quality
print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: (1599, 11)
# Target shape: (1599,)

# %% [markdown]
# ## 3. Preprocess the Data
# Here, we handle any missing values and scale the features. A ColumnTransformer bundles these steps into a single pipeline for all numeric columns. Even if this dataset has no missing values, setting up the imputer is good practice. Scaling ensures the model treats all features equally, without bias toward larger numerical ranges.

# %%
numeric_features = X.columns
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features)
    ]
)

# %% [markdown]
# Numerical feature.

# %% [markdown]
# ##4. Create the Pipeline
#
# Now we bring everything together. This step combines preprocessing and modeling into a single pipeline. The pipeline keeps everything neat and repeatable. Instead of applying preprocessing separately, we connect it directly to the model. This way, the same preprocessing is applied during both training and prediction.

# %%
pipeline = Pipeline(steps=[
    _________________________,
    _________________________
])

# %% [markdown]
# ##5. Split the Data
# We divide the dataset into training and test sets. This ensures we have unseen data to evaluate how well our model performs.

# %%
X_train, X_test, y_train, y_test = _________________________
print("Training set shape:", X_train.shape)
print("Test set shape:", X_test.shape)

# %% [markdown]
# ##6. Train the Model
# The pipeline handles both preprocessing and training automatically.
#
# This is where the magic happens. The pipeline takes care of scaling, imputing, and training, so we don’t need to worry about applying these steps manually.

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object'))])),
#                 ('model', KNeighborsClassifier(n_neighbors=4))])

# %% [markdown]
# ##7. Evaluate the Model
# Finally, we test the model on the unseen test data and check its performance.

# %%
y_pred = ______________________
print("\nAccuracy:", _____________________)
print("\nClassification Report:")
print(_____________________________)

# %% [markdown]
# ##+ Save Your Pipeline!
# Sometimes, we don’t want to retrain the model or redo all the preprocessing steps every time. By saving the pipeline, we can reuse it later without repeating everything. Here’s how we can do it.

# %%
import joblib

joblib.dump(pipeline, 'wine_quality_pipeline.pkl')

# %% [markdown]
# When you need the pipeline later, you can load it back from the file.

# %%
# Load the pipeline
loaded_pipeline = joblib.load('wine_quality_pipeline.pkl')

# Use the loaded pipeline
y_pred_new = loaded_pipeline.predict(X_test)
print("Predictions:", y_pred_new)
